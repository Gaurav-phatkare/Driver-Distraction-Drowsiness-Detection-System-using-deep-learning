# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaurav-phatkare/Driver-Distraction-Drowsiness-Detection-System-using-deep-learning/blob/main/Training_Files/CNN_hyertuned_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import cv2
import tensorflow_hub as hub
from tensorflow.keras import layers

# %%
# !unzip /content/drive/MyDrive/abcd.zip -d /content/EyeDataset

# %%
def print_directory_structure(directory, indent=0):
    for item in os.listdir(directory):
        path = os.path.join(directory, item)
        if os.path.isdir(path):
            print(f"{'    ' * indent}{os.path.basename(path)} - {len(os.listdir(path))} files")
            print_directory_structure(path, indent + 1)

eye_directory = '/content/Eyes_Dataset_v03'

print_directory_structure(eye_directory)
# Out:
# test_dataset - 2 files
#     open_eye - 2197 files
#     closed_eye - 2078 files
# training_dataset - 2 files
#     open_eye - 32169 files
#     closed_eye - 31492 files
# validation_dataset - 2 files
#     open_eye - 8586 files
#     closed_eye - 8376 files

# %%
files = 0
for _, _, filenames in os.walk(eye_directory):
  files += len(filenames)

print(f"Total images in dataset : {files}")
# Out:
# Total images in dataset : 84898

# %%
train_dir = "/content/Eyes_Dataset_v03/training_dataset/"
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   horizontal_flip=True) # don't use rescale = 1./255

train_generator = train_datagen.flow_from_directory( train_dir,
                                                     target_size=(128,128),
                                                     batch_size=32,
                                                     shuffle=True,
                                                     class_mode='categorical'
                                                     )


val_dir = "/content/Eyes_Dataset_v03/validation_dataset/"
validation_datagen = ImageDataGenerator(rescale = 1./255,
                                   horizontal_flip=True)


validation_generator =  validation_datagen.flow_from_directory( val_dir,
                                                                target_size=(128,128),
                                                                batch_size=32,
                                                                class_mode='categorical'
                                                                )
# Out:
# Found 63661 images belonging to 2 classes.
# Found 16962 images belonging to 2 classes.

# %%
images, labels = train_generator.next()
images.shape
# Out:
# (32, 128, 128, 3)

# %% [markdown]
# ## CNN model With Hypertuning

# %%
cnn_model04 = tf.keras.Sequential([
    tf.keras.layers.Conv2D(20,
                           3,
                           activation = tf.keras.layers.LeakyReLU(alpha = 0.3),
                           input_shape = (128,128,3)),
    tf.keras.layers.MaxPool2D(pool_size = 2),

    # tf.keras.layers.Conv2D(10, 3, activation = 'relu'),
    # tf.keras.layers.MaxPool2D(),

    tf.keras.layers.Conv2D(10, 3, activation = 'relu'),
    tf.keras.layers.MaxPool2D(),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100, activation = tf.keras.layers.LeakyReLU(alpha = 0.3)),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(50, activation = tf.keras.layers.LeakyReLU(alpha = 0.3)),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(2, activation = 'softmax')
])

# compile a model
cnn_model04.compile(loss = 'categorical_crossentropy',
                optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-4),
                metrics=[tf.keras.metrics.CategoricalAccuracy(),tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# %%
cnn_model04.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 126, 126, 20)      560
#
#  max_pooling2d_8 (MaxPoolin  (None, 63, 63, 20)        0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 61, 61, 10)        1810
#
#  max_pooling2d_9 (MaxPoolin  (None, 30, 30, 10)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 9000)              0
#
#  dense_12 (Dense)            (None, 100)               900100
#
#  dropout_8 (Dropout)         (None, 100)               0
#
#  dense_13 (Dense)            (None, 50)                5050
#
#  dropout_9 (Dropout)         (None, 50)                0
#
#  dense_14 (Dense)            (None, 2)                 102
#
# =================================================================
# Total params: 907622 (3.46 MB)
# Trainable params: 907622 (3.46 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cnn_model04_hist = cnn_model04.fit(train_generator,
                        epochs = 20,
                        steps_per_epoch = len(train_generator),
                        validation_data = validation_generator,
                        validation_steps = len(validation_generator))
# Out:
# Epoch 1/20
# 1990/1990 [==============================] - 122s 37ms/step - loss: 0.3102 - categorical_accuracy: 0.8706 - precision_4: 0.8706 - recall_4: 0.8706 - val_loss: 0.1929 - val_categorical_accuracy: 0.9267 - val_precision_4: 0.9267 - val_recall_4: 0.9267
# Epoch 2/20
# 1990/1990 [==============================] - 74s 37ms/step - loss: 0.1771 - categorical_accuracy: 0.9350 - precision_4: 0.9350 - recall_4: 0.9350 - val_loss: 0.1471 - val_categorical_accuracy: 0.9474 - val_precision_4: 0.9474 - val_recall_4: 0.9474
# Epoch 3/20
# 1990/1990 [==============================] - 73s 36ms/step - loss: 0.1496 - categorical_accuracy: 0.9455 - precision_4: 0.9455 - recall_4: 0.9455 - val_loss: 0.1423 - val_categorical_accuracy: 0.9464 - val_precision_4: 0.9464 - val_recall_4: 0.9464
# Epoch 4/20
# 1990/1990 [==============================] - 74s 37ms/step - loss: 0.1334 - categorical_accuracy: 0.9521 - precision_4: 0.9521 - recall_4: 0.9521 - val_loss: 0.1189 - val_categorical_accuracy: 0.9568 - val_precision_4: 0.9568 - val_recall_4: 0.9568
# Epoch 5/20
# 1990/1990 [==============================] - 74s 37ms/step - loss: 0.1226 - categorical_accuracy: 0.9559 - precision_4: 0.9559 - recall_4: 0.9559 - val_loss: 0.1106 - val_categorical_accuracy: 0.9599 - val_precision_4: 0.9599 - val_recall_4: 0.9599
# Epoch 6/20
# 1990/1990 [==============================] - 81s 41ms/step - loss: 0.1145 - categorical_accuracy: 0.9588 - precision_4: 0.9588 - recall_4: 0.9588 - val_loss: 0.1020 - val_categorical_accuracy: 0.9637 - val_precision_4: 0.9637 - val_recall_4: 0.9637
# Epoch 7/20
# 1990/1990 [==============================] - 71s 36ms/step - loss: 0.1061 - categorical_accuracy: 0.9632 - precision_4: 0.9632 - recall_4: 0.9632 - val_loss: 0.0962 - val_categorical_accuracy: 0.9663 - val_precision_4: 0.9663 - val_recall_4: 0.9663
# Epoch 8/20
# 1990/1990 [==============================] - 73s 37ms/step - loss: 0.0997 - categorical_accuracy: 0.9647 - precision_4: 0.9647 - recall_4: 0.9647 - val_loss: 0.0906 - val_categorical_accuracy: 0.9679 - val_precision_4: 0.9679 - val_recall_4: 0.9679
# Epoch 9/20
# 1990/1990 [==============================] - 74s 37ms/step - loss: 0.0946 - categorical_accuracy: 0.9662 - precision_4: 0.9662 - recall_4: 0.9662 - val_loss: 0.0914 - val_categorical_accuracy: 0.9682 - val_precision_4: 0.9682 - val_recall_4: 0.9682
# Epoch 10/20
# 1990/1990 [==============================] - 73s 37ms/step - loss: 0.0924 - categorical_accuracy: 0.9674 - precision_4: 0.9674 - recall_4: 0.9674 - val_loss: 0.0844 - val_categorical_accuracy: 0.9698 - val_precision_4: 0.9698 - val_recall_4: 0.9698
# Epoch 11/20
# 1990/1990 [==============================] - 77s 39ms/step - loss: 0.0879 - categorical_accuracy: 0.9687 - precision_4: 0.9687 - recall_4: 0.9687 - val_loss: 0.0807 - val_categorical_accuracy: 0.9718 - val_precision_4: 0.9718 - val_recall_4: 0.9718
# Epoch 12/20
# 1990/1990 [==============================] - 74s 37ms/step - loss: 0.0839 - categorical_accuracy: 0.9700 - precision_4: 0.9700 - recall_4: 0.9700 - val_loss: 0.0821 - val_categorical_accuracy: 0.9719 - val_precision_4: 0.9719 - val_recall_4: 0.9719
# Epoch 13/20
# 1990/1990 [==============================] - 73s 37ms/step - loss: 0.0838 - categorical_accuracy: 0.9697 - precision_4: 0.9697 - recall_4: 0.9697 - val_loss: 0.0884 - val_categorical_accuracy: 0.9689 - val_precision_4: 0.9689 - val_recall_4: 0.9689
# Epoch 14/20
# 1990/1990 [==============================] - 81s 41ms/step - loss: 0.0799 - categorical_accuracy: 0.9719 - precision_4: 0.9719 - recall_4: 0.9719 - val_loss: 0.0738 - val_categorical_accuracy: 0.9737 - val_precision_4: 0.9737 - val_recall_4: 0.9737
# Epoch 15/20
# 1990/1990 [==============================] - 76s 38ms/step - loss: 0.0803 - categorical_accuracy: 0.9720 - precision_4: 0.9720 - recall_4: 0.9720 - val_loss: 0.0752 - val_categorical_accuracy: 0.9728 - val_precision_4: 0.9728 - val_recall_4: 0.9728
# Epoch 16/20
# 1990/1990 [==============================] - 74s 37ms/step - loss: 0.0766 - categorical_accuracy: 0.9733 - precision_4: 0.9733 - recall_4: 0.9733 - val_loss: 0.0703 - val_categorical_accuracy: 0.9751 - val_precision_4: 0.9751 - val_recall_4: 0.9751
# Epoch 17/20
# 1990/1990 [==============================] - 82s 41ms/step - loss: 0.0745 - categorical_accuracy: 0.9738 - precision_4: 0.9738 - recall_4: 0.9738 - val_loss: 0.0765 - val_categorical_accuracy: 0.9743 - val_precision_4: 0.9743 - val_recall_4: 0.9743
# Epoch 18/20
# 1990/1990 [==============================] - 81s 41ms/step - loss: 0.0718 - categorical_accuracy: 0.9749 - precision_4: 0.9749 - recall_4: 0.9749 - val_loss: 0.0672 - val_categorical_accuracy: 0.9767 - val_precision_4: 0.9767 - val_recall_4: 0.9767
# Epoch 19/20
# 1990/1990 [==============================] - 78s 39ms/step - loss: 0.0708 - categorical_accuracy: 0.9749 - precision_4: 0.9749 - recall_4: 0.9749 - val_loss: 0.0682 - val_categorical_accuracy: 0.9778 - val_precision_4: 0.9778 - val_recall_4: 0.9778
# Epoch 20/20
# 1990/1990 [==============================] - 74s 37ms/step - loss: 0.0687 - categorical_accuracy: 0.9751 - precision_4: 0.9751 - recall_4: 0.9751 - val_loss: 0.0661 - val_categorical_accuracy: 0.9774 - val_precision_4: 0.9774 - val_recall_4: 0.9774

# %%
fig1 = plt.gcf()
plt.plot(cnn_model04_hist.history['categorical_accuracy'])
plt.plot(cnn_model04_hist.history['val_categorical_accuracy'])
# plt.axis(ymin=0.4,ymax=1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
fig1 = plt.gcf()
plt.plot(cnn_model04_hist.history['loss'])
plt.plot(cnn_model04_hist.history['val_loss'])

plt.grid()
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def predict_and_display(image_path, model):
    class_ls = ['closed_eye', 'open_eyes']

    img_height, img_width = 128,128


    image = cv2.imread(image_path)
    r_eye = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    r_eye = cv2.resize(r_eye, (img_height, img_width))
    r_eye = r_eye / 255.0
    r_eye = r_eye.reshape((-1, img_height, img_width, 3))


    pred = model.predict(r_eye)


    predicted_class = int(np.argmax(pred))


    plt.imshow(r_eye.reshape((img_height, img_width, 3)))
    plt.title(f"Predicted Class: {class_ls[predicted_class]}")
    plt.axis('off')
    plt.show()

    return predicted_class
image_path = "/content/Eyes_Dataset_v03/test_dataset/closed_eye/s0012_01754_0_1_0_2_0_01.png"
predicted_class = predict_and_display(image_path, cnn_model04)
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
image_path = "/content/Eyes_Dataset_v03/test_dataset/open_eye/s0014_06142_0_0_1_0_1_01.png"
predicted_class = predict_and_display(image_path, cnn_model04)
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %%
cnn_model04.save("/content/model/cnn_v04.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## EfficientNet-imagenet

# %%
efficientnet_v2_imagenet1k_b0= "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet1k_b0/feature_vector/2"

# setting trainable layers to false
def create_model(model_url, num_classes = 2):

  feature_extractor_layer = hub.KerasLayer(model_url,
                                           trainable = False,
                                           name = 'feature_extraction_layer',
                                           input_shape = (128,128,3))

  model = tf.keras.Sequential([
      feature_extractor_layer,
      layers.Dense(num_classes, activation ='softmax',name = 'output_layer')

  ])

  return model

# %%
efficientnet_imagenet1k_b0_model = create_model(model_url = efficientnet_v2_imagenet1k_b0, num_classes = 2)

efficientnet_imagenet1k_b0_model.compile(loss = 'categorical_crossentropy',
                           optimizer = tf.keras.optimizers.Adam(),
                           metrics=[tf.keras.metrics.CategoricalAccuracy(),tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

efficientnet_imagenet1k_b0_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  feature_extraction_layer (  (None, 1280)              5919312
#  KerasLayer)
#
#  output_layer (Dense)        (None, 2)                 2562
#
# =================================================================
# Total params: 5921874 (22.59 MB)
# Trainable params: 2562 (10.01 KB)
# Non-trainable params: 5919312 (22.58 MB)
# _________________________________________________________________

# %%
# fit the model

efficientnet_imagenet_history = efficientnet_imagenet1k_b0_model.fit(
    train_generator,
    epochs = 15,
    steps_per_epoch = len(train_generator),
    validation_data = validation_generator,
    validation_steps = len(validation_generator)
)
# Out:
# Epoch 1/15
# 1990/1990 [==============================] - 87s 44ms/step - loss: 0.2098 - categorical_accuracy: 0.9217 - precision_5: 0.9217 - recall_5: 0.9217 - val_loss: 0.1729 - val_categorical_accuracy: 0.9363 - val_precision_5: 0.9363 - val_recall_5: 0.9363
# Epoch 2/15
# 1990/1990 [==============================] - 82s 41ms/step - loss: 0.1577 - categorical_accuracy: 0.9438 - precision_5: 0.9438 - recall_5: 0.9438 - val_loss: 0.1583 - val_categorical_accuracy: 0.9447 - val_precision_5: 0.9447 - val_recall_5: 0.9447
# Epoch 3/15
# 1990/1990 [==============================] - 81s 41ms/step - loss: 0.1406 - categorical_accuracy: 0.9505 - precision_5: 0.9505 - recall_5: 0.9505 - val_loss: 0.1343 - val_categorical_accuracy: 0.9533 - val_precision_5: 0.9533 - val_recall_5: 0.9533
# Epoch 4/15
# 1990/1990 [==============================] - 81s 41ms/step - loss: 0.1308 - categorical_accuracy: 0.9547 - precision_5: 0.9547 - recall_5: 0.9547 - val_loss: 0.1261 - val_categorical_accuracy: 0.9573 - val_precision_5: 0.9573 - val_recall_5: 0.9573
# Epoch 5/15
# 1990/1990 [==============================] - 84s 42ms/step - loss: 0.1232 - categorical_accuracy: 0.9572 - precision_5: 0.9572 - recall_5: 0.9572 - val_loss: 0.1206 - val_categorical_accuracy: 0.9593 - val_precision_5: 0.9593 - val_recall_5: 0.9593
# Epoch 6/15
# 1990/1990 [==============================] - 82s 41ms/step - loss: 0.1175 - categorical_accuracy: 0.9591 - precision_5: 0.9591 - recall_5: 0.9591 - val_loss: 0.1181 - val_categorical_accuracy: 0.9589 - val_precision_5: 0.9589 - val_recall_5: 0.9589
# Epoch 7/15
# 1990/1990 [==============================] - 87s 44ms/step - loss: 0.1132 - categorical_accuracy: 0.9604 - precision_5: 0.9604 - recall_5: 0.9604 - val_loss: 0.1269 - val_categorical_accuracy: 0.9571 - val_precision_5: 0.9571 - val_recall_5: 0.9571
# Epoch 8/15
# 1990/1990 [==============================] - 86s 43ms/step - loss: 0.1113 - categorical_accuracy: 0.9607 - precision_5: 0.9607 - recall_5: 0.9607 - val_loss: 0.1100 - val_categorical_accuracy: 0.9619 - val_precision_5: 0.9619 - val_recall_5: 0.9619
# Epoch 9/15
# 1990/1990 [==============================] - 83s 42ms/step - loss: 0.1072 - categorical_accuracy: 0.9629 - precision_5: 0.9629 - recall_5: 0.9629 - val_loss: 0.1113 - val_categorical_accuracy: 0.9608 - val_precision_5: 0.9608 - val_recall_5: 0.9608
# Epoch 10/15
# 1990/1990 [==============================] - 82s 41ms/step - loss: 0.1062 - categorical_accuracy: 0.9626 - precision_5: 0.9626 - recall_5: 0.9626 - val_loss: 0.1041 - val_categorical_accuracy: 0.9646 - val_precision_5: 0.9646 - val_recall_5: 0.9646
# Epoch 11/15
# 1990/1990 [==============================] - 82s 41ms/step - loss: 0.1019 - categorical_accuracy: 0.9643 - precision_5: 0.9643 - recall_5: 0.9643 - val_loss: 0.1040 - val_categorical_accuracy: 0.9645 - val_precision_5: 0.9645 - val_recall_5: 0.9645
# Epoch 12/15
# 1990/1990 [==============================] - 82s 41ms/step - loss: 0.1010 - categorical_accuracy: 0.9651 - precision_5: 0.9651 - recall_5: 0.9651 - val_loss: 0.1012 - val_categorical_accuracy: 0.9644 - val_precision_5: 0.9644 - val_recall_5: 0.9644
# Epoch 13/15
# 1990/1990 [==============================] - 83s 41ms/step - loss: 0.0998 - categorical_accuracy: 0.9656 - precision_5: 0.9656 - recall_5: 0.9656 - val_loss: 0.1008 - val_categorical_accuracy: 0.9643 - val_precision_5: 0.9643 - val_recall_5: 0.9643
# Epoch 14/15
# 1990/1990 [==============================] - 82s 41ms/step - loss: 0.0977 - categorical_accuracy: 0.9661 - precision_5: 0.9661 - recall_5: 0.9661 - val_loss: 0.1021 - val_categorical_accuracy: 0.9657 - val_precision_5: 0.9657 - val_recall_5: 0.9657
# Epoch 15/15
# 1990/1990 [==============================] - 87s 44ms/step - loss: 0.0962 - categorical_accuracy: 0.9663 - precision_5: 0.9663 - recall_5: 0.9663 - val_loss: 0.1033 - val_categorical_accuracy: 0.9634 - val_precision_5: 0.9634 - val_recall_5: 0.9634

# %%
fig1 = plt.gcf()
plt.plot(efficientnet_imagenet_history.history['categorical_accuracy'])
plt.plot(efficientnet_imagenet_history.history['val_categorical_accuracy'])
# plt.axis(ymin=0.4,ymax=1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()
